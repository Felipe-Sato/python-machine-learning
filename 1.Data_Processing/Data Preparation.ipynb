# %% [markdown]
# # Pre Processing the Dataset

# %% [markdown]
# This Jupyter Notebook consolidates, normalizes and separates the data into datasets to be utilized on the project.

# %% [markdown]
# ## Consolitating the Data

# %% [markdown]
# This step focuses on unifying all CSV files downloaded into one file to serve as the dataset for the project.

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
df1 = pd.read_csv("../1.UNSW-NB15/UNSW-NB15_1.csv")
df1.head()
# Out:
#    59.166.0.0   1390  149.171.126.6    53  udp  CON  0.001055  132  164  31  \
# 0  59.166.0.0  33661  149.171.126.9  1024  udp  CON  0.036133  528  304  31
# 1  59.166.0.6   1464  149.171.126.7    53  udp  CON  0.001119  146  178  31
# 2  59.166.0.5   3593  149.171.126.5    53  udp  CON  0.001209  132  164  31
# 3  59.166.0.3  49664  149.171.126.0    53  udp  CON  0.001169  146  178  31
# 4  59.166.0.0  32119  149.171.126.9   111  udp  CON  0.078339  568  312  31
#
#    ...  0.17   3  7  1  3.1  1.1  1.2  1.3  Unnamed: 47  0.18
# 0  ...     0   2  4  2    3    1    1    2          NaN     0
# 1  ...     0  12  8  1    2    2    1    1          NaN     0
# 2  ...     0   6  9  1    1    1    1    1          NaN     0
# 3  ...     0   7  9  1    1    1    1    1          NaN     0
# 4  ...     0   2  4  2    3    1    1    2          NaN     0
#
# [5 rows x 49 columns]

# %%
df2 = pd.read_csv("../1.UNSW-NB15/UNSW-NB15_2.csv", header = None)
df3 = pd.read_csv("../1.UNSW-NB15/UNSW-NB15_3.csv", header = None)
df4 = pd.read_csv("../1.UNSW-NB15/UNSW-NB15_4.csv", header = None)

# %%
df2.columns = df.columns
df3.columns = df.columns
df4.columns = df.columns

# %%
df1.shape, df2.shape, df3.shape, df4.shape
# Out:
# ((700000, 49), (700001, 49), (700001, 49), (440044, 49))

# %%
data = df1
data = data.append(df2)
data = data.append(df3)
data = data.append(df4)

# %%
data.shape
data.head()
# Out:
#    59.166.0.0   1390  149.171.126.6    53  udp  CON  0.001055  132  164  31  \
# 0  59.166.0.0  33661  149.171.126.9  1024  udp  CON  0.036133  528  304  31
# 1  59.166.0.6   1464  149.171.126.7    53  udp  CON  0.001119  146  178  31
# 2  59.166.0.5   3593  149.171.126.5    53  udp  CON  0.001209  132  164  31
# 3  59.166.0.3  49664  149.171.126.0    53  udp  CON  0.001169  146  178  31
# 4  59.166.0.0  32119  149.171.126.9   111  udp  CON  0.078339  568  312  31
#
#    ...  0.17   3  7  1  3.1  1.1  1.2  1.3  Unnamed: 47  0.18
# 0  ...     0   2  4  2    3    1    1    2          NaN     0
# 1  ...     0  12  8  1    2    2    1    1          NaN     0
# 2  ...     0   6  9  1    1    1    1    1          NaN     0
# 3  ...     0   7  9  1    1    1    1    1          NaN     0
# 4  ...     0   2  4  2    3    1    1    2          NaN     0
#
# [5 rows x 49 columns]

# %%
data.to_csv('../2.Dataset/UNSW-NB15.csv')

# %% [markdown]
# ## Finding errors and null valor in the dataset

# %% [markdown]
# Here we'll prepare to find and fix errors and null values on the dataset.

# %%
import socket as sk
import struct as st
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("../2.Dataset/UNSW-NB15.csv", index_col = [0])
df.shape
df.head()
# Out:
#    59.166.0.0   1390  149.171.126.6    53  udp  CON  0.001055  132  164  31  \
# 0  59.166.0.0  33661  149.171.126.9  1024  udp  CON  0.036133  528  304  31
# 1  59.166.0.6   1464  149.171.126.7    53  udp  CON  0.001119  146  178  31
# 2  59.166.0.5   3593  149.171.126.5    53  udp  CON  0.001209  132  164  31
# 3  59.166.0.3  49664  149.171.126.0    53  udp  CON  0.001169  146  178  31
# 4  59.166.0.0  32119  149.171.126.9   111  udp  CON  0.078339  568  312  31
#
#    ...  0.17   3  7  1  3.1  1.1  1.2  1.3  Unnamed: 47  0.18
# 0  ...     0   2  4  2    3    1    1    2          NaN     0
# 1  ...     0  12  8  1    2    2    1    1          NaN     0
# 2  ...     0   6  9  1    1    1    1    1          NaN     0
# 3  ...     0   7  9  1    1    1    1    1          NaN     0
# 4  ...     0   2  4  2    3    1    1    2          NaN     0
#
# [5 rows x 49 columns]

# %%
#router's address 
df.loc[df.srcip == '192168241243','srcip'] = '192.168.241.243'
df.loc[df.dstip == '192168241243','dstip'] = '192.168.241.243'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [29], in <cell line: 2>()
#       1 #router's address
# ----> 2 df.loc[df.srcip == '192168241243','srcip'] = '192.168.241.243'
#       3 df.loc[df.dstip == '192168241243','dstip'] = '192.168.241.243'
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'srcip'

# %%
#Converting Hex to Base 10
df.loc[df.dsport == '0xc0a8','dsport'] = '49320'
df.loc[df.dsport == '0x20205321','dsport'] = '538989345'
df.loc[df.dsport == '0xcc09','dsport'] = '52233'
df.loc[df.sport == '0x000b','sport'] = '11'
df.loc[df.sport == '0x000c','sport'] = '12'

# %%
#Converting IP to a numerical
df['srcip'] = df.srcip.apply(lambda x: st.unpack('!I', sk.inet_aton(x))[0])
df['dstip'] = df.dstip.apply(lambda x: st.unpack('!I', sk.inet_aton(x))[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [30], in <cell line: 2>()
#       1 #Converting IP to a numerical
# ----> 2 df['srcip'] = df.srcip.apply(lambda x: st.unpack('!I', sk.inet_aton(x))[0])
#       3 df['dstip'] = df.dstip.apply(lambda x: st.unpack('!I', sk.inet_aton(x))[0])
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'srcip'

# %%
# Getting rid of unnecessary column
df.drop(columns='attack_cat', inplace = True)

#Handling missing values
df.drop(df.loc[df.dsport == '-'].index, inplace = True)
df.drop(df.loc[df.sport == '-'].index, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [31], in <cell line: 2>()
#       1 # Getting rid of unnecessary column
# ----> 2 df.drop(columns='attack_cat', inplace = True)
#       4 #Handling missing values
#       5 df.drop(df.loc[df.dsport == '-'].index, inplace = True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['attack_cat'] not found in axis"

# %%
# Handling inconsistent data
df.dur = df.dur.str.replace(',','.')
df.ackdat = df.ackdat.str.replace(',','.')
df.loc[df.ct_ftp_cmd == ' ', 'ct_ftp_cmd'] = df.ct_flw_http_mthd.mean()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [32], in <cell line: 2>()
#       1 # Handling inconsistent data
# ----> 2 df.dur = df.dur.str.replace(',','.')
#       3 df.ackdat = df.ackdat.str.replace(',','.')
#       4 df.loc[df.ct_ftp_cmd == ' ', 'ct_ftp_cmd'] = df.ct_flw_http_mthd.mean()
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dur'

# %%
#Convert objet 
df.sport.astype(int)
df.dsport.astype(int)
df.ackdat.astype(float)
df.dur.astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [33], in <cell line: 2>()
#       1 #Convert objet
# ----> 2 df.sport.astype(int)
#       3 df.dsport.astype(int)
#       4 df.ackdat.astype(float)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'sport'

# %%
#Handling missing values
df.ct_flw_http_mthd.fillna(df.ct_flw_http_mthd.mean(), inplace = True)
df.is_ftp_login.fillna(df.is_ftp_login .mean(), inplace = True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [34], in <cell line: 2>()
#       1 #Handling missing values
# ----> 2 df.ct_flw_http_mthd.fillna(df.ct_flw_http_mthd.mean(), inplace = True)
#       3 df.is_ftp_login.fillna(df.is_ftp_login .mean(), inplace = True)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'ct_flw_http_mthd'

# %%
# Handling categorical data
Encoder = LabelEncoder()
df.proto = Encoder.fit_transform(df.proto)
df.state = Encoder.fit_transform(df.state)
df.service = Encoder.fit_transform(df.service)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [35], in <cell line: 3>()
#       1 # Handling categorical data
#       2 Encoder = LabelEncoder()
# ----> 3 df.proto = Encoder.fit_transform(df.proto)
#       4 df.state = Encoder.fit_transform(df.state)
#       5 df.service = Encoder.fit_transform(df.service)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'proto'
